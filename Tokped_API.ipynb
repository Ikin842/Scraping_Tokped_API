# %% [markdown]
# # Import Package

# %%
import requests
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
list_lokasi = []
list_toko = []
list_rating = []
list_harga = []
list_nama = []

list_url_product = []
list_url_gambar = []
list_diskon = []
list_jumlah_review = []
list_category = []
list_rating_average = []

# %% [markdown]
# # Function & Main Code

# %%
def scrape_link_product(parameter):
    
    url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'
    payload = [{
    "operationName": "SearchProductQueryV4",
    "variables": {
        "params":parameter
    },
    "query":"query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    }]
    
    req = requests.post(url, json=payload).json()
    rows = req[0]['data']['ace_search_product_v4']['data']['products']

# %%
def scrape_data(parameter):
    
    url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'
    payload = [{
    "operationName": "SearchProductQueryV4",
    "variables": {
        "params":parameter
    },
    "query":"query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    }]
    
    req = requests.post(url, json=payload).json()
    rows = req[0]['data']['ace_search_product_v4']['data']['products']
    
    for i in range(0, len(rows)):
        nama_product = rows[i]['name']
        list_nama.append(nama_product)

        harga = rows[i]['price']
        list_harga.append(harga)

        toko = rows[i]['shop']['name']
        list_toko.append(toko)

        lokasi = rows[i]['shop']['city']
        list_lokasi.append(lokasi)
        
        rating = rows[i]['rating']
        list_rating.append(rating)
        
        rating_average = rows[i]['ratingAverage']
        list_rating_average.append(rating_average)
        
        category = rows[i]['categoryName']
        list_category.append(category)
        
        jumlah_review = rows[i]['countReview']
        list_jumlah_review.append(jumlah_review)
        
        diskon = rows[i]['discountPercentage']
        list_diskon.append(diskon)
        
        url_gambar = rows[i]['imageUrl']
        list_url_gambar.append(url_gambar)
        
        url_product = 'https://www.tokopedia.com' + rows[i]['gaKey'].replace('/searchproduct/handphone-tablet/handphone/android-os/handphone', '')
        list_url_product.append(list_url_product)

# %%
# cari = 'handphone'
cari = str(input('Masukan keyword yang dicari : '))
for i in tqdm(range(1, 3)):
# 
    parameter = "device=desktop&navsource=&ob=23&page={}&q={}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=d8fa26671511f17608d6fd76bcf84872&user_addressId=&user_cityId=176&user_districtId=2274&user_id=&user_lat=&user_long=&user_postCode=&user_warehouseId=12210375&variants=". format(i, cari, (i-1)*60)
    scrape_data(parameter)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # Result Scraping

# %%
dictionary = {
    'nama_product' : list_nama, 'harga': list_harga, 'lokasi' : list_lokasi,
    'toko': list_toko, 'rating': list_rating, 'rating_average' : list_rating_average, 'jumlah_review': list_jumlah_review,
    'categoty' : list_category, 'diskon': list_diskon, 'url_gambar':list_url_gambar, 'url_product':list_url_product
}

df = pd.DataFrame.from_dict(dictionary, orient='index')
df = df.T
df
# Out:
#                                           nama_product        harga  \
# 0    Rotate Case Casing Cover 360 Leather Samsung T...     Rp50.000
# 1               Xiaomi Redmi 10A 3/32 GB Garansi Resmi  Rp1.279.900
# 2                        Infinix HOT 12 Play 4/64 BNIB  Rp1.510.000
# 3         Redmi A1 2022 Garansi Resmi Xiaomi Indonesia  Rp1.060.000
# 4        PROMO Samsung Galaxy A04 4/64GB Garansi Resmi  Rp1.543.000
# ..                                                 ...          ...
# 115       Realme Narzo 50i Prime 4/64 GB Garansi Resmi  Rp1.149.000
# 116         PROMO Realme Narzo 50i PRIME Garansi Resmi  Rp1.395.000
# 117  Samsung Galaxy A04 3/32 4/64 RAM 3 4 ROM 32 64...  Rp1.399.000
# 118  REALME NARZO 50i PRIME RAM 3/32 GB - 4/64GB GA...  Rp1.138.000
# 119  Xiaomi Redmi Note 11 Pro 5G 8/128GB 6/128 GB G...  Rp3.237.000
#
#             lokasi                toko rating rating_average jumlah_review  \
# ...

# %%
df.to_csv('Scraping_tokopedia_API.csv', index= False)
